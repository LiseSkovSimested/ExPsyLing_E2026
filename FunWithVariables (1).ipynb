# %% [markdown]
# # Strings, Ints & Floats Practice Set
#
# Exercises for [LSP Sections 4.6–4.9](https://ethanweed.github.io/pythonbook/02.02-more_python_concepts.html#arguments).
#
# These are exercises to practice the basic variables we talked about on Thursday. Work through the exercises in order: they build on each other. I would suggest working in pairs or small groups. Where it says "predict", take they time to talk about it and actually make and write down your predictions, before you run the code. You can make a markdown cell in this notebook to write down your answers to the "predict" and "discuss" questions. Do as many of the exercises as you can during the instructor session. Of course you are welcome to keep working on these at home, if you don't finish, but I do not expect you to. Do as many as you can, but _take the time to make sure you all understand each one._ Understanding is more important than completion!
#
# ---

# %% [markdown]
# ## Warm-up
#
# You don't need to write any new code here, just write down your predictions in a markdown cell, and use `type()` to check your answers.

# %% [markdown]
# ### 1. Type detective
#
# Predict what `type()` reports for each line, then run it.

# %%
x = 42
y = 3.14
z = "42"
w = "3.14"

# I predict that x is an integer, y is a float, z and w are strings.
# Out:
# str

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
type(z)
# Out:
# str

# %%
type(w)
# Out:
# str

# %% [markdown]
# **Discuss:** Look at the variables `z` and `x`, above. They hold the same digits — why does Python treat them differently? Try `x + z` and explain the error.

# %% [markdown]
# Answer: Because they are strings

# %% [markdown]
# ### 2. Floats can be... weird
#
# Predict first, then run:

# %% [markdown]
# Prediction: from the book: "This answer makes no sense if we think that 0.1 is exactly 0.1, but makes more sense if we understand that to Python, 0.1 is just an approximation of the answer to 1/10. Now, most of the time this is not going to matter much, but it could make a difference, so it is good to be aware of it"

# %% [markdown]
# I predict that the 1.5 and 2.2 round up/down will both be 2 because python rounds up/down to the nearest EVEN number, in this case 2.

# %%
print(0.1 + 0.1 + 0.1)
print(round(1.5))
print(round(2.5))
# Out:
# 0.30000000000000004
# 2
# 2

# %% [markdown]
# **Discuss:** why doesn't the first line print `0.3`? How can it possibly be that `round(1.5)` and `round(2.5)` produce these answers? Does Python not understand how math works? We didn't discuss this in class, but you can find the answers in [LSP Chapter 4.8.2](https://ethanweed.github.io/pythonbook/02.02-more_python_concepts.html#floats)

# %% [markdown]
# ---

# %% [markdown]
# ## Core string skills
#
# Concatenation, repetition, and the string methods from [LSP Section 4.8.3](https://ethanweed.github.io/pythonbook/02.02-more_python_concepts.html#strings): `.title()`, `.upper()`, `.split()`, `.join()`. We glanced at some of these in class, but not all of them, and not in any depth. Consult the section in the book, and see how far you can get.

# %% [markdown]
# ### 3. Mad libs concatenation
#
# Build the sentence `"Ethan drinks 5 cups of coffee a day."` using only `+` concatenation. You'll hit a `TypeError` on the number — fix it with `str()`.

# %%
name = "Ethan "
beverage = "coffee "
number = "5 "
action = "drinks "
instrument = "cups of "
time = "a day"

print(name + action + number + instrument + beverage + time)
# Out:
# Ethan drinks 5 cups of coffee a day

# %% [markdown]
# ### 4. Repeat pattern
#
# Use `*` to print a 20-character divider line, then `"meow"` three times in a row with no spaces. Consult [LSP Section 4.8.3](https://ethanweed.github.io/pythonbook/02.02-more_python_concepts.html#strings) for help.

# %% [markdown]
# **Extend:** build a little ASCII box around a word using repetition and concatenation together. Your answer should look something like this (but with a word of choice):

# %% [raw]
# **********
# * coffee *
# **********

# %% [markdown]
# I don't get what I'm to do?

# %% [markdown]
# ### 5. Fun with cases
#
# Below is a string variable ``s``. Use Python's built-in string methods (the things you can see when you run``dir(s)``) print this string in UPPER CASE, lower case, and Title Case.

# %%
s = "tHE fARMER killED tHe DUckliNg" # (deep cut for all you McGregor fans out there)
s.upper()
# Out:
# 'THE FARMER KILLED THE DUCKLING'

# %%
s = "tHE fARMER killED tHe DUckliNg"
s.title()
# Out:
# 'The Farmer Killed The Duckling'

# %%
s = "tHE fARMER killED tHe DUckliNg"
s.lower()
# Out:
# 'the farmer killed the duckling'

# %% [markdown]
# ### 6. Split and count
#
# You already know the functions ``print()``and ``dir()``. Try the function `len()` on the variable ``word``, below. What does ``len()``do?

# %%
word = "coffee"
len(word)
# Out:
# 6

# %% [markdown]
# It counts the number of characters

# %% [markdown]
# Now try the string method ``.split()``on the sentence below. What does it do? What happens if you use ``len()``on the output of the split sentence?

# %%
sentence = "the quick brown fox jumps over the lazy dog"
sentence.split()
# Out:
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %% [markdown]
# It divides the sentence into words.

# %%
sentence = "the quick brown fox jumps over the lazy dog"
sentence.split()
len(sentence)
# Out:
# 43

# %% [markdown]
# Then it counts the number of characters including spaces

# %% [markdown]
# ### 7. Join rebuild
#
# Use `.join()` to turn this list back into one sentence, with spaces between words. Look at [LSP Section 4.8.3](https://ethanweed.github.io/pythonbook/02.02-more_python_concepts.html#strings) for similar examples.

# %%
words = ["Python", "is", "fun"]
" ".join(words)
# Out:
# 'Python is fun'

# %% [markdown]
# **Extend:** join the same list with `"-"` and with `", "` instead of a space. Notice `.join()` lives on the separator, not the list.

# %%
words = ["Python", "is", "fun"]
"-".join(words)
# Out:
# 'Python-is-fun'

# %%
words = ["Python", "is", "fun"]
", ".join(words)
# Out:
# 'Python, is, fun'

# %% [markdown]
# ---

# %% [markdown]
# ## Challenge
#
# Learn to use optional arguments. Check out [LSP Section 4.9](https://ethanweed.github.io/pythonbook/02.02-more_python_concepts.html#arguments) for similar examples.

# %% [markdown]
# ### 8. Find-and-replace story
#
# Replace every `"galaxy"` with `"suburb"` in the paragraph below. Then use the optional third argument to `.replace()` so only the *first* occurrence changes, and compare the two outputs.

# %%
story = "a long time ago in a galaxy far, far away, the galaxy council met in the galaxy hall"
story.replace('galaxy', 'suburb')
# Out:
# 'a long time ago in a suburb far, far away, the suburb council met in the suburb hall'

# %%
story = "a long time ago in a galaxy far, far away, the galaxy council met in the galaxy hall"
story.replace('galaxy', 'suburb', 1)
# Out:
# 'a long time ago in a suburb far, far away, the galaxy council met in the galaxy hall'

# %% [markdown]
# **Discuss:** what's required for `.replace()` to work, and what's optional? What does Python use as the default when the count is left out?

# %% [markdown]
# It needs at least 2 arguments: The one that needs replacing and the one it is replaced with. There is an optional third argument, the number, so how many times should it replace it.

# %% [markdown]
# ---

# %% [markdown]
# ### 9. Username generator
#
# Given a first name (string) and a birth year (int), build a lowercase, space-free username: `"Ethan"` + `1973` → `"ethan1973"`.

# %%
first = "Ethan"
year = 1973

username = {'first': 'Ethan',
            'year': 1973}
print(first + year)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 6
#       2 year = 1973
#       3
#       4 username = {'first': 'Ethan',
#       5             'year': 1973}
# ----> 6 print(first + year)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# **Extend:** wrap it in a function `make_username(first, year)` that also strips spaces from multi-word names ("Ethan Weed" → "ethanweed1973"), then test it on your own name.
