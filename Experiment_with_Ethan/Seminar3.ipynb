# %%
import pandas as pd

# %%
raw = pd.read_csv('/work/ExPsyLing_E2026/Experiment_with_Ethan/combined_data.csv')

# %% [markdown]
# HUSK at indsætte /work/ foran stien

# %%
#raw.head(50)

# %%
list(raw) #how to see the colum names
# Out:
# ['participant_id',
#  'component_num',
#  'url',
#  'meta',
#  'sender',
#  'sender_type',
#  'sender_id',
#  'ended_on',
#  'duration',
#  'time_run',
#  'time_render',
#  'time_show',
#  'time_end',
#  'time_commit',
#  'timestamp',
#  'time_switch',
#  'response',
#  'response_action',
#  'prime',
#  'target',
#  'condition',
#  'soa_condition',
#  'congruence',
#  'correct_response',
#  'correctResponse',
#  'correct']

# %%
cols = ['participant_id', 
        'sender', 
        'duration', 
        'prime',
        'target',
        'response', 
        'condition', 
        'soa_condition', 
        'congruence', 
        'correct_response', 
        'correct', ]
#cols is short for colums
    #making a list of all the stuff we need

# %%
df = raw[cols]
#df is short for dataframe

# %%
df = df[df['sender'] == 'target'] 
#the two == means "is equal to". Så vi fjerner alle de colunner, hvor det ikke er "target" der er afsender. Så vi kun har det vi faktisk skal bruge.

# %%
df
# Out:
#        participant_id               sender   duration prime target response  \
# 0                  51              Wecome1     499.56   NaN    NaN      NaN
# 1                  51              Wecome2     499.52   NaN    NaN      NaN
# 2                  51              Wecome3     499.52   NaN    NaN      NaN
# 3                  51        Instructions1    9061.10   NaN    NaN      NaN
# 4                  51      Instructions 1a    2279.00   NaN    NaN      NaN
# ...               ...                  ...        ...   ...    ...      ...
# 15632              69           Short Loop   85426.00   NaN    NaN      NaN
# 15633              69                Break     868.30   NaN    NaN      NaN
# 15634              69       Short Sequence   86318.40   NaN    NaN      NaN
# 15635              69  Experiment Sequence  183618.50   NaN    NaN      NaN
# 15636              69                 root  216385.18   NaN    NaN      NaN
#
# ...

# %%
df['sender'].unique()
#tjekker om der er andet end "target" som "sender"
# Out:
# <StringArray>
# ['target']
# Length: 1, dtype: str

# %%
df = df[df['condition'] != 'practice'] #finds everything that is NOT practice
df = df.drop(columns = ['sender']) #fjerner kolonnen med 'sender'

# %%
df
# Out:
#        participant_id  duration  prime target response        condition  \
# 40                 51    520.14   roof  PIANO        m  Inc_Synth_Synth
# 47                 51    640.66  sheep   BULL        n      Inc_Nat_Nat
# 54                 51    597.74   fort   GOAT        n    Inc_Synth_Nat
# 61                 51    495.68   pear   PEAR        n          Con_Nat
# 68                 51    556.86  olive  MOTOR        m    Inc_Nat_Synth
# ...               ...       ...    ...    ...      ...              ...
# 15606              69    699.20   belt   BELT        m        Con_Synth
# 15612              69    580.20  daisy  DAISY        n          Con_Nat
# 15618              69    577.90  peach   SHED        m    Inc_Nat_Synth
# 15624              69    661.10   rake  HUSKY        n    Inc_Synth_Nat
# 15630              69    709.20   fern  PETAL        n      Inc_Nat_Nat
#
#       soa_condition   congruence correct_response correct
# ...

# %%
df.loc[df['target'] == 'BULL', 'correct_response'] = 'n'

# %%
df
# Out:
#        participant_id  duration  prime target response        condition  \
# 40                 51    520.14   roof  PIANO        m  Inc_Synth_Synth
# 47                 51    640.66  sheep   BULL        n      Inc_Nat_Nat
# 54                 51    597.74   fort   GOAT        n    Inc_Synth_Nat
# 61                 51    495.68   pear   PEAR        n          Con_Nat
# 68                 51    556.86  olive  MOTOR        m    Inc_Nat_Synth
# ...               ...       ...    ...    ...      ...              ...
# 15606              69    699.20   belt   BELT        m        Con_Synth
# 15612              69    580.20  daisy  DAISY        n          Con_Nat
# 15618              69    577.90  peach   SHED        m    Inc_Nat_Synth
# 15624              69    661.10   rake  HUSKY        n    Inc_Synth_Nat
# 15630              69    709.20   fern  PETAL        n      Inc_Nat_Nat
#
#       soa_condition   congruence correct_response correct
# ...

# %%
#df['accuracy'] = df['response'] == df['correct_response'] #still working on fixing the "bull" mistake
#we made a new column called accuracy to fix it

# %%
df
# Out:
#        participant_id  duration  prime target response        condition  \
# 40                 51    520.14   roof  PIANO        m  Inc_Synth_Synth
# 47                 51    640.66  sheep   BULL        n      Inc_Nat_Nat
# 54                 51    597.74   fort   GOAT        n    Inc_Synth_Nat
# 61                 51    495.68   pear   PEAR        n          Con_Nat
# 68                 51    556.86  olive  MOTOR        m    Inc_Nat_Synth
# ...               ...       ...    ...    ...      ...              ...
# 15606              69    699.20   belt   BELT        m        Con_Synth
# 15612              69    580.20  daisy  DAISY        n          Con_Nat
# 15618              69    577.90  peach   SHED        m    Inc_Nat_Synth
# 15624              69    661.10   rake  HUSKY        n    Inc_Synth_Nat
# 15630              69    709.20   fern  PETAL        n      Inc_Nat_Nat
#
#       soa_condition   congruence correct_response correct
# ...

# %%
df_grouped = df.groupby(['soa_condition', 'congruence']).mean(['duration'])
#ethan will fix the error later....
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df_grouped = df.groupby(['soa_condition', 'congruence']).mean(['duration'])
#       2 #ethan will fix the error later....
#
# File /opt/conda/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
# ...

# %%
#run when Ethan has fixed the above error
#df_grouped = df_grouped.reset_index()
#df_grouped

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
ax = sns.barplot(data = df_grouped, x = 'congruence', y = 'duration', hue = 'soa_condition')
